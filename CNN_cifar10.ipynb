# %% [markdown]
# <a href="https://colab.research.google.com/github/MohammedAmine0012/project-violence-detection/blob/main/CNN_cifar10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Convolutional Neural Network (CNN)
#
# Image Classification (CIFAR-10) by CNN
#
# Training the CNN model by SGD with Dropout and Weight Decay.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.datasets as dsets
import torchvision.transforms as transforms
import torch.nn.functional as F

# %%
# load CIFAR-10 data
train_dataset = dsets.CIFAR10('./data',
                         train=True,
                         download=True,
                         transform=transforms.Compose([
                             transforms.ToTensor(),
                             transforms.Normalize(
                                [0.5, 0.5, 0.5],  # RGB 平均
                                [0.5, 0.5, 0.5]   # RGB 標準偏差
                                )
                         ]))

test_dataset = dsets.CIFAR10('./data',
                         train=False,
                         download=True,
                         transform=transforms.Compose([
                             transforms.ToTensor(),
                             transforms.Normalize(
                                 [0.5, 0.5, 0.5],  # RGB 平均
                                 [0.5, 0.5, 0.5]  # RGB 標準偏差
                             )
                         ]))

#print(len(train_Dataset))

train_dataset, valid_dataset = torch.utils.data.random_split(  # データセットの分割
      train_dataset,   # 分割するデータセット
      [40000, 10000])  # 分割数

print('train_dataset = ', len(train_dataset))
print('valid_dataset = ', len(valid_dataset))
print('test_dataset = ', len(test_dataset))
# Out:
# 100%|██████████| 170M/170M [00:03<00:00, 44.4MB/s]
# train_dataset =  40000
# valid_dataset =  10000
# test_dataset =  10000

# %%
# Set up DataLoader
batch=128

train_loader = torch.utils.data.DataLoader(
        dataset=train_dataset,
        batch_size=batch,
        shuffle=True
    )

valid_loader = torch.utils.data.DataLoader(
        dataset=valid_dataset,
        batch_size=batch,
        shuffle=True
    )

test_loader = torch.utils.data.DataLoader(
        dataset=test_dataset,
        batch_size=batch,
        shuffle=True
    )

# %%
class Network(nn.Module):
    def __init__(self):
        super(Network, self).__init__()
        self.conv1 = nn.Conv2d(3,32,3, padding=1)
        self.pool1 = nn.MaxPool2d(2,2)
        self.dropout1 = nn.Dropout(0.2)
        self.conv2 = nn.Conv2d(32,32,3, padding=1)
        self.pool2 = nn.MaxPool2d(2,2)
        self.dropout2 = nn.Dropout(0.2)
        self.fc1 = nn.Linear(32*8*8, 128)
        self.dropout3 = nn.Dropout(0.2)
        self.fc2 = nn.Linear(128, 10)


    def forward(self, x):
        x = self.pool1(F.relu(self.conv1(x)))
        x = self.dropout1(x)
        x = self.pool2(F.relu(self.conv2(x)))
        x = self.dropout2(x)
        x = x.view(-1, 32 * 8 * 8)
        x = F.relu(self.fc1(x))
        x = self.dropout3(x)
        x = self.fc2(x)
        return x

net = Network()
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)

if torch.cuda.is_available():
  net.cuda()

print('Network architecture for CNN\n', net)
# Out:
# cuda
# Network architecture for CNN
#  Network(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout1): Dropout(p=0.2, inplace=False)
#   (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout2): Dropout(p=0.2, inplace=False)
#   (fc1): Linear(in_features=2048, out_features=128, bias=True)
#   (dropout3): Dropout(p=0.2, inplace=False)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
# optimizing
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9, weight_decay=0.001)
#optimizer = optim.AdamW(net.parameters(), lr=0.01, weight_decay=0.001)

# %%
# Define Class names
classes = ('plane', 'car', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck')

# %%
###  training
print ('training start ...')
num_epochs = 100

# initialize list for plot graph after training
train_loss_list, train_acc_list, val_loss_list, val_acc_list = [], [], [], []

for epoch in range(num_epochs):
    # initialize each epoch
    train_loss, train_acc, val_loss, val_acc = 0, 0, 0, 0

    # ======== train_mode (Backprop) ======
    net.train()
    for i, (images, labels) in enumerate(train_loader):  # get mini batch samples
        #viewで28×28×１画像を１次元に変換し、deviceへ転送
#        images, labels = images.view(-1, 28*28*1).to(device), labels.to(device)
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()  # Reset the gradients
        outputs = net(images)  # forward computation
        loss = criterion(outputs, labels)  # loss
        loss.backward()  # backward computation
        optimizer.step()  # optimization

    # ======== eval_mode (training samples) ======
    net.eval()
    with torch.no_grad():  # no computation of gradients
      for images, labels in train_loader:
#          images, labels = images.view(-1, 28*28*1).to(device), labels.to(device)
          images, labels = images.to(device), labels.to(device)
          outputs = net(images)
          loss = criterion(outputs, labels)
          train_loss += loss.item()
          acc = (outputs.max(1)[1] == labels).sum()
          train_acc += acc.item()
    avg_train_loss = train_loss / len(train_loader.dataset)
    avg_train_acc = train_acc / len(train_loader.dataset)

    # ======== eval_mode (validation samples) ======
    net.eval()
    with torch.no_grad():  # no comptutation of gradients
      for images, labels in valid_loader:
#          images, labels = images.view(-1, 28*28*1).to(device), labels.to(device)
          images, labels = images.to(device), labels.to(device)
          outputs = net(images)
          loss = criterion(outputs, labels)
          val_loss += loss.item()
          acc = (outputs.max(1)[1] == labels).sum()
          val_acc += acc.item()
    avg_val_loss = val_loss / len(valid_loader.dataset)
    avg_val_acc = val_acc / len(valid_loader.dataset)

    # print log
    print ('Epoch [{}/{}] train Loss: {loss:.4f}, train acc: {acc:.4f} | val_loss: {val_loss:.4f}, val_acc: {val_acc:.4f}'
                   .format(epoch+1, num_epochs, i+1, loss=avg_train_loss, acc=avg_train_acc, val_loss=avg_val_loss, val_acc=avg_val_acc))

    # append list for polt graph after training
    train_loss_list.append(avg_train_loss)
    train_acc_list.append(avg_train_acc)
    val_loss_list.append(avg_val_loss)
    val_acc_list.append(avg_val_acc)
# Out:
# training start ...
# Epoch [1/100] train Loss: 0.0172, train acc: 0.2293 | val_loss: 0.0174, val_acc: 0.2358
# Epoch [2/100] train Loss: 0.0153, train acc: 0.3212 | val_loss: 0.0155, val_acc: 0.3280
# Epoch [3/100] train Loss: 0.0144, train acc: 0.3527 | val_loss: 0.0145, val_acc: 0.3623
# Epoch [4/100] train Loss: 0.0138, train acc: 0.3854 | val_loss: 0.0140, val_acc: 0.3857
# Epoch [5/100] train Loss: 0.0133, train acc: 0.4019 | val_loss: 0.0134, val_acc: 0.4053
# Epoch [6/100] train Loss: 0.0128, train acc: 0.4253 | val_loss: 0.0129, val_acc: 0.4247
# Epoch [7/100] train Loss: 0.0122, train acc: 0.4503 | val_loss: 0.0123, val_acc: 0.4473
# Epoch [8/100] train Loss: 0.0117, train acc: 0.4710 | val_loss: 0.0119, val_acc: 0.4669
# Epoch [9/100] train Loss: 0.0114, train acc: 0.4804 | val_loss: 0.0115, val_acc: 0.4758
# Epoch [10/100] train Loss: 0.0111, train acc: 0.4934 | val_loss: 0.0114, val_acc: 0.4856
# Epoch [11/100] train Loss: 0.0109, train acc: 0.5041 | val_loss: 0.0112, val_acc: 0.4918
# Epoch [12/100] train Loss: 0.0107, train acc: 0.5127 | val_loss: 0.0110, val_acc: 0.5042
# Epoch [13/100] train Loss: 0.0106, train acc: 0.5222 | val_loss: 0.0109, val_acc: 0.5053
# Epoch [14/100] train Loss: 0.0103, train acc: 0.5322 | val_loss: 0.0107, val_acc: 0.5153
# Epoch [15/100] train Loss: 0.0102, train acc: 0.5338 | val_loss: 0.0106, val_acc: 0.5198
# Epoch [16/100] train Loss: 0.0100, train acc: 0.5476 | val_loss: 0.0104, val_acc: 0.5281
# Epoch [17/100] train Loss: 0.0099, train acc: 0.5551 | val_loss: 0.0102, val_acc: 0.5332
# Epoch [18/100] train Loss: 0.0097, train acc: 0.5620 | val_loss: 0.0101, val_acc: 0.5434
# Epoch [19/100] train Loss: 0.0096, train acc: 0.5712 | val_loss: 0.0100, val_acc: 0.5486
# Epoch [20/100] train Loss: 0.0094, train acc: 0.5787 | val_loss: 0.0099, val_acc: 0.5547
# Epoch [21/100] train Loss: 0.0093, train acc: 0.5770 | val_loss: 0.0098, val_acc: 0.5548
# Epoch [22/100] train Loss: 0.0092, train acc: 0.5887 | val_loss: 0.0097, val_acc: 0.5616
# Epoch [80/100] train Loss: 0.0046, train acc: 0.8103 | val_loss: 0.0069, val_acc: 0.6979
# Epoch [81/100] train Loss: 0.0046, train acc: 0.8085 | val_loss: 0.0068, val_acc: 0.6982
# Epoch [82/100] train Loss: 0.0045, train acc: 0.8140 | val_loss: 0.0068, val_acc: 0.6997
# Epoch [83/100] train Loss: 0.0045, train acc: 0.8177 | val_loss: 0.0068, val_acc: 0.7030
# Epoch [84/100] train Loss: 0.0045, train acc: 0.8157 | val_loss: 0.0068, val_acc: 0.6971
# Epoch [85/100] train Loss: 0.0045, train acc: 0.8164 | val_loss: 0.0068, val_acc: 0.6988
# Epoch [86/100] train Loss: 0.0044, train acc: 0.8221 | val_loss: 0.0068, val_acc: 0.7010
# Epoch [87/100] train Loss: 0.0043, train acc: 0.8288 | val_loss: 0.0067, val_acc: 0.7012
# Epoch [88/100] train Loss: 0.0043, train acc: 0.8274 | val_loss: 0.0067, val_acc: 0.7068
# Epoch [89/100] train Loss: 0.0042, train acc: 0.8291 | val_loss: 0.0067, val_acc: 0.7030
# Epoch [90/100] train Loss: 0.0042, train acc: 0.8338 | val_loss: 0.0067, val_acc: 0.7069
# Epoch [91/100] train Loss: 0.0041, train acc: 0.8367 | val_loss: 0.0066, val_acc: 0.7089
# Epoch [92/100] train Loss: 0.0041, train acc: 0.8395 | val_loss: 0.0067, val_acc: 0.7092
# Epoch [93/100] train Loss: 0.0040, train acc: 0.8421 | val_loss: 0.0066, val_acc: 0.7078
# Epoch [94/100] train Loss: 0.0040, train acc: 0.8447 | val_loss: 0.0066, val_acc: 0.7072
# Epoch [95/100] train Loss: 0.0040, train acc: 0.8450 | val_loss: 0.0067, val_acc: 0.7055
# Epoch [96/100] train Loss: 0.0040, train acc: 0.8406 | val_loss: 0.0067, val_acc: 0.7082
# Epoch [97/100] train Loss: 0.0038, train acc: 0.8498 | val_loss: 0.0066, val_acc: 0.7070
# Epoch [98/100] train Loss: 0.0038, train acc: 0.8488 | val_loss: 0.0066, val_acc: 0.7087
# Epoch [99/100] train Loss: 0.0038, train acc: 0.8519 | val_loss: 0.0066, val_acc: 0.7088
# Epoch [100/100] train Loss: 0.0038, train acc: 0.8469 | val_loss: 0.0067, val_acc: 0.7074

# %%
# ======== eval_mode (test samples) ======
net.eval()
with torch.no_grad():
    total = 0
    test_acc = 0
    for images, labels in test_loader:
#        images, labels = images.view(-1, 28 * 28 * 1 ).to(device), labels.to(device)
        images, labels = images.to(device), labels.to(device)
        outputs = net(images)
        test_acc += (outputs.max(1)[1] == labels).sum().item()
        total += labels.size(0)
    print('test_accuracy: {} %'.format(100 * test_acc / total))
import os

# ... your existing code ...

# Before saving the model:
os.makedirs('./trained_models', exist_ok=True)  # Create the directory if it doesn't exist

# save weights (You can save the model by uncomment the following line)
torch.save(net, './trained_models/CNN_cifar10.pth')
# Out:
# test_accuracy: 70.93 %

# %%
# plot graph
import matplotlib.pyplot as plt

plt.figure()
plt.plot(range(num_epochs), train_loss_list, color='blue', linestyle='-', label='train_loss')
plt.plot(range(num_epochs), val_loss_list, color='green', linestyle='--', label='val_loss')
plt.ylim([0.0,0.02])
plt.legend()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title('Training and validation loss')
plt.grid()
plt.savefig('CNN_cifar10_loss.png')
plt.show()

plt.figure()
plt.plot(range(num_epochs), train_acc_list, color='blue', linestyle='-', label='train_acc')
plt.plot(range(num_epochs), val_acc_list, color='green', linestyle='--', label='val_acc')
plt.ylim([0.0, 1.0])
plt.legend()
plt.xlabel('epoch')
plt.ylabel('acc')
plt.title('Training and validation accuracy')
plt.grid()
plt.savefig('CNN_cifar10_acc.png')
plt.show()
